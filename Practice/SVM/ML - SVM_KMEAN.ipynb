# %% [markdown]
# ## Support Vector Machines (SVM) and K-means

# %% [markdown]
# ### Aims:
#     * Generate own data to test classifiers
#     * Practice Support Vector Machine - tuning soft margin and kernel parameters
#     * Practise K-means and Kernel K-means

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
# %matplotlib inline
import pylab as plt
from matplotlib.colors import ListedColormap


# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %% [markdown]
# ### Generate data to test binary classifiers
#
# Generate two dimensional Gaussian distributed data for two different classes
#
#  * Generate multivariate Guassian random samples:
#          https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.random.multivariate_normal.html
#
#  * Plot is based on $$\mbox{class 0}: \mu_0 = \begin{bmatrix} 1 \\ 2 \end{bmatrix}, \Sigma_0=\begin{bmatrix} 1 & 0 \\ 0 & 1 \end{bmatrix}$$, $$\mbox{class 1}: \mu_1 = \begin{bmatrix} 7 \\ 7 \end{bmatrix}, \Sigma_1=\begin{bmatrix} 2 & 0 \\ 0 & 2 \end{bmatrix}$$

# %%
np.random.seed(seed=1)

# Data of class 0
mean_class1 = (1, 2)
cov_class1 = [[1,0],[0,1]]
x_class1 = np.random.multivariate_normal(mean_class1, cov_class1, size=100)
t_class1 = np.zeros_like(x_class1)[:,0]

# Data of class 1
mean_class2 = (7, 7)
cov_class2 = [[2,0],[0,2]]
x_class2 = np.random.multivariate_normal(mean_class2, cov_class2, size=100)
t_class2 = np.ones_like(x_class2)[:,0]

# Combine data and labels into X and t
X = np.vstack((x_class1, x_class2))
t = np.hstack((t_class1, t_class2))

plt.scatter(X[:,0], X[:,1], c=t, cmap=cmap_bold, edgecolor='k', s=100)

# %% [markdown]
# ### Use SVM on generated data, with different margins and kernerls.
#
# Reference to SVM in sklearn:
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
h = .02
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# %% [markdown]
# #### Test hard margin SVM without kernel projection
#
# ##### The SVC function in sklearn implements a SVM with soft margin. It has a parameter `C` controling how soft the margin is. Based on your understanding of soft margin SVM, choose a value for `C` that is equivalent to a hard margin SVM.

# %%
from sklearn.svm import SVC

clf = SVC(kernel='linear', C=1000)
clf.fit(X,t)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

plt.scatter(X[:,0], X[:,1], c=t, cmap=cmap_bold, edgecolor='k')
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("SVM Classification - Hard Margin")
# Out:
# Text(0.5, 1.0, 'SVM Classification - Hard Margin')

# %% [markdown]
# #### Test soft margin SVM without kernel projection

# %%
from sklearn.svm import SVC

clf = SVC(kernel='linear', C=0.05)
clf.fit(X,t)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

plt.scatter(X[:,0], X[:,1], c=t, cmap=cmap_bold, edgecolor='k', s=100)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("SVM Classification")
# Out:
# Text(0.5, 1.0, 'SVM Classification')

# %% [markdown]
# #### Test non linear data.

# %%
from sklearn import cluster, datasets

n_samples = 200
np.random.seed(seed=1)
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)

X = noisy_circles[0]
t = noisy_circles[1]
plt.scatter(X[:, 0], X[:, 1], c=t, cmap=cmap_bold, edgecolor='k', s=100)

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
h = .02
x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# %% [markdown]
# #### Train SVM classifier with the RBF kernel:
#     * Test difference gamma (1e-3, 1e+3) and margin values C (1e-3, 1e+2)

# %%
from sklearn.svm import SVC

clf = SVC(kernel='rbf', C=1e-3, gamma=1)
clf.fit(X,t)
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

Z = Z.reshape(xx.shape)
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

plt.scatter(X[:, 0], X[:, 1], c=t, cmap=cmap_bold, edgecolor='k', s=100)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("SVM Classification")
plt.tight_layout()

# %% [markdown]
# #### Task 2.4: Use cross-validation to determine best  `C` and `gamma` values

# %%
from sklearn.model_selection import cross_val_score

gamma_list = [1e-3, 1e-2, 1e-1, 1e-0, 1e+1, 1e+2, 1e+3]
C_list = [1e-3, 1e-2, 1e-1, 1e-0, 1e+1, 1e+2]

for i in C_list:
    for j in gamma_list:
        clf = SVC(kernel='rbf', C=i, gamma=j).fit(X,t)
        score = np.mean(cross_val_score(clf, X, t, cv=5))
        if score > 0.8:
            print('C:'+ str(i) + ' Gamma:' + str(j) + ' Score:', score)
# Out:
# C:0.001 Gamma:1.0 Score: 0.9949999999999999
# C:0.001 Gamma:10.0 Score: 1.0
# C:0.001 Gamma:100.0 Score: 0.975
# C:0.01 Gamma:1.0 Score: 0.9949999999999999
# C:0.01 Gamma:10.0 Score: 1.0
# C:0.01 Gamma:100.0 Score: 0.975
# C:0.1 Gamma:1.0 Score: 1.0
# C:0.1 Gamma:10.0 Score: 1.0
# C:0.1 Gamma:100.0 Score: 0.975
# C:1.0 Gamma:1.0 Score: 1.0
# C:1.0 Gamma:10.0 Score: 1.0
# C:1.0 Gamma:100.0 Score: 0.9949999999999999
# C:1.0 Gamma:1000.0 Score: 0.8150000000000001
# C:10.0 Gamma:0.1 Score: 1.0
# C:10.0 Gamma:1.0 Score: 1.0
# C:10.0 Gamma:10.0 Score: 1.0
# C:10.0 Gamma:100.0 Score: 0.9949999999999999
# C:10.0 Gamma:1000.0 Score: 0.85
# C:100.0 Gamma:0.1 Score: 1.0
# C:100.0 Gamma:1.0 Score: 1.0
# C:100.0 Gamma:10.0 Score: 1.0
# C:100.0 Gamma:100.0 Score: 0.9949999999999999
# C:100.0 Gamma:1000.0 Score: 0.85

# %% [markdown]
# ### Test clustering on 'Moon data'

# %%
np.random.seed(seed=1)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
X = noisy_moons[0]
t = noisy_moons[1]
plt.scatter(X[:, 0], X[:, 1], c=t, cmap=cmap_bold, edgecolor='k', s=100)

# %% [markdown]
# #### Fit `KMeans` on the data and color each data point with its cluster membership
# Reference:
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)
Z = kmeans.predict(X)

plt.scatter(X[:, 0], X[:, 1], c=Z, cmap=cmap_bold, edgecolor='k', s=100)

# %% [markdown]
# #### Use `SpectralClustering` for Kernel K-Means with RBF and gamma. Test different Gamma values.
#     https://scikit-learn.org/stable/modules/generated/sklearn.cluster.SpectralClustering.html
# `gamma` = 15
# `affinity` = 'rbf'

# %%
from sklearn.cluster import SpectralClustering
clustering = SpectralClustering(n_clusters=2,gamma=15,affinity='rbf', random_state=0).fit(X)
plt.scatter(X[:, 0], X[:, 1], c=clustering.labels_, cmap=cmap_bold, edgecolor='k', s=100)
